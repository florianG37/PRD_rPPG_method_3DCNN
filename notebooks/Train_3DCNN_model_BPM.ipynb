# %% [markdown]
# # Implementation of a new rPPG method
#
# ## Part 1 : Notebook for the training of the 3D-CNN model
#
# This jupyter notebook file is composed of different sections allowing to train a Deep Learning neural network to estimate the heart rate of a patient with a simple video sequence.  With this jupyter notebook file, the results of the model can also be validated.
#
# ![General Schema](./img/general_scheme.JPG)
#
# The objective is to generate a functional model in view of integrating it into the pyVHR Framework. ([Link](https://ieeexplore.ieee.org/document/9272290)) ([GitHub](https://github.com/phuselab/pyVHR))
#
# This file is based on the implementation described in the following article :
# Frédéric Bousefsaf, Alain Pruski, Choubeila Maaoui, 3D convolutional neural networks for remote pulse rate measurement and mapping from facial video, Applied Sciences, vol. 9, n° 20, 4364 (2019). ([Link](https://www.mdpi.com/2076-3417/9/20/4364)) ([GitHub](https://github.com/frederic-bousefsaf/ippg-3dcnn))

# %% [markdown]
# ## Importing libraries
#
# Previously , you have to install theses python librairies :
# * tensorflow
# * matplotlib
# * scipy
# * numpy
# * opencv-python

# %%
import os
#RUN ON CPU 
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

#Tensorflow/KERAS
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import ModelCheckpoint
from tensorflow.python.keras.models import model_from_json
from tensorflow.python.keras.layers import ZeroPadding3D, Dense, Activation,Conv3D,MaxPooling3D,AveragePooling3D,Flatten,Dropout
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.models import model_from_json

# Numpy / Matplotlib / OpenCV / Scipy
import numpy as np
import matplotlib.pyplot as plt
import cv2
import scipy.io

# %% [markdown]
# ## Setting of input data
#
# Input Data = IMAGE_WIDTH * IMAGE_HEIGHT * LENGTH_VIDEOS
#
# Units = (X pixels) * (Y pixels) * (N frames)

# %%
LENGTH_VIDEO = 60 #frames
IMAGE_WIDTH = 25 #pixels
IMAGE_HEIGHT = 25 #pixels
IMAGE_CHANNELS = 1 #1 or 2 or 3

#Time notion
SAMPLING = 1 / 30 #30 Hz
t = np.linspace(0, LENGTH_VIDEO * SAMPLING - SAMPLING, LENGTH_VIDEO)

# %% [markdown]
# ## Setting of output data
#
# A class represents an interval \[X,Y\] BPM frequencies.
#
# For example, Class 1 can set the rating between 55 and 57.5 BPM.

# %%
# Available Outputs
HEART_RATES = np.linspace(55, 240, 75)
NB_CLASSES = len(HEART_RATES)

# prepare labels and label categories
labels = np.zeros(NB_CLASSES + 1)

# %% [markdown]
# ## Setting of training session

# %%
# CONSTANTS
NB_VIDEOS_BY_CLASS_TRAIN = 1
NB_VIDEOS_BY_CLASS_VALIDATION = 100

EPOCHS = 1
CONTINUE_TRAINING = True #load or not a old trained model
MIXED_DATA = False

RESULTS_PATH = "./model"

# %% [markdown]
# ## Binarization of classes
#
# Class 1 : (1, 0, 0, 0, 0, ... , 0)
#
# Class 2 : (0, 1, 0, 0, 0, ... , 0)
#
# ...
#
# Class n : (0, 0, 0, 0, 0, ... , 1)

# %%
for i in range(NB_CLASSES + 1):
    labels[i] = i
labels_cat = np_utils.to_categorical(labels)

# %% [markdown]
# ## Definition of the 3D CNN model
#
# ![Model](./img/model_structure.jpg)

# %%
# DEFINE MODEL
model = Sequential()

#feature extraction
model.add(Conv3D(filters=32, kernel_size=(LENGTH_VIDEO-2,IMAGE_HEIGHT-5,IMAGE_WIDTH-5), input_shape=(LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Flatten())

#Classification
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(NB_CLASSES + 1, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 3, 6, 6, 32)       742432
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 1, 3, 3, 32)       0
# _________________________________________________________________
# activation (Activation)      (None, 1, 3, 3, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 3, 3, 32)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               147968
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 76)                38988
# =================================================================
# Total params: 929,388
# Trainable params: 929,388
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Process for artificial data creation
#
# For more information, the process is described with more detail in the article cited in the introduction. However, here is a summary diagram:
#
# ![Data Generation](./img/data_generation.jpg)
#
#
# Original version of the implementation of this process : [GitHub](https://github.com/frederic-bousefsaf/ippg-3dcnn/tree/master/train)

# %% [markdown]
# ## Trend generation function for artificial data creation

# %%
def generate_trend(length, order, min, max, offset):

    if (order==1):   # linear
        tend = np.linspace(min, max, length)

    elif (order==2): # quadratic
        if (offset==0):
            tend = np.linspace(0, 1, length)
            tend = tend*tend
            tend = tend-min
            tend = max*tend/np.max(tend)

        else:
            tend = tend = np.linspace(-0.5, 0.5, length)
            tend = tend*tend
            tend = tend-min
            tend = 0.5*max*tend/np.max(tend)

    elif (order==3): # cubic
        if (offset==0):
            tend = np.linspace(0, 1, length)
            tend = tend*tend*tend
            tend = tend-min
            tend = max*tend/np.max(tend)

        else:
            tend = tend = np.linspace(-0.5, 0.5, length)
            tend = tend*tend*tend
            tend = tend-min
            tend = 0.5*max*tend/np.max(tend)
    return tend

# %% [markdown]
# ## Trend generation parameters for artificial data creation

# %%
# Tendencies (linear, 2nd order, 3rd order)
TENDANCIES_MIN = (-3,-1,-1)
TENDANCIES_MAX = (3,1,1)
TENDANCIES_ORDER = (1,2,3)

# coefficients for the fitted-ppg method
a0 = 0.440240602542388
a1 = -0.334501803331783
b1 = -0.198990393984879
a2 = -0.050159136439220
b2 = 0.099347477830878
w = 2 * np.pi

# %% [markdown]
# ## Train Data generation

# %%
xtrain = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_TRAIN, LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS))
ytrain = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_TRAIN, NB_CLASSES + 1))

c = 0

for i_freq in range(len(HEART_RATES)):

    for i_videos in range(NB_VIDEOS_BY_CLASS_TRAIN):

        t2 = t + (np.random.randint(low=0, high=33) * SAMPLING)   # phase
        signal = a0 + a1 * np.cos(t2 * w * HEART_RATES[i_freq] / 60) + b1 * np.sin(t2 * w * HEART_RATES[i_freq] / 60) + a2 * np.cos(2 * t2 * w * HEART_RATES[i_freq] / 60) + b2 * np.sin(2 * t2 * w * HEART_RATES[i_freq] / 60)
        signal = signal - np.min(signal)
        signal = signal / np.max(signal)

        r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
        trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

        signal = np.expand_dims(signal + trend, 1)
        signal = signal - np.min(signal)

        img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT))
        img = np.transpose(img, axes=(0,2,1))

        img = img / (IMAGE_HEIGHT * IMAGE_WIDTH)
        
        amplitude = np.random.uniform(low=1.5, high=4)
        noise_energy = amplitude * 0.25 * np.random.uniform(low=1, high=10) / 100

        for j in range(0, LENGTH_VIDEO):
            temp = 255 * ((amplitude * img[:,:,j]) + np.random.normal(size=(IMAGE_HEIGHT, IMAGE_WIDTH), loc=0.5, scale=0.25) * noise_energy)
            temp[temp < 0] = 0 
            xtrain[c,j,:,:,0] = temp.astype('uint8') / 255.0

        xtrain[c] = xtrain[c] - np.mean(xtrain[c])
        ytrain[c] = labels_cat[i_freq]

        c = c + 1


# constant image noise (gaussian distribution)
for i_videos in range(NB_VIDEOS_BY_CLASS_TRAIN):
    r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
    trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

    # add a tendancy on noise
    signal = np.expand_dims(trend, 1)
    img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT)) / (IMAGE_HEIGHT * IMAGE_WIDTH)
    img = np.expand_dims(np.transpose(img, axes=(1,0,2)), 3)

    xtrain[c] = np.expand_dims(np.random.normal(size=(LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH)) / 50, 3) + img
    xtrain[c] = xtrain[c] - np.mean(xtrain[c])
    ytrain[c] = labels_cat[NB_CLASSES]
    c = c + 1

print('Train data generation done.')
# Out:
# Train data generation done.

# %% [markdown]
# # Training phase
#
# ## Start a training session + save

# %%
# load model
if (CONTINUE_TRAINING == True):
    model = model_from_json(open(f'{RESULTS_PATH}/model_conv3D.json').read())
    model.load_weights(f'{RESULTS_PATH}/weights_conv3D.h5')
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
if(MIXED_DATA == True):
    data = np.load('./dataSplited.npz')
    xtrain = np.concatenate((xtrain, data['a']), axis=0)
    ytrain =  np.concatenate((ytrain, data['b']), axis=0)

    indices = np.arange(xtrain.shape[0])
    np.random.shuffle(indices)
    xtrain = xtrain[indices]
    ytrain = ytrain[indices]
    
#start training
model.fit(xtrain, ytrain, epochs = EPOCHS, batch_size=256, verbose=1)

#save data
model_json = model.to_json()
open(f'{RESULTS_PATH}/model_conv3D.json', 'w').write(model_json)
model.save_weights(f'{RESULTS_PATH}/weights_conv3D.h5', overwrite=True)
print('A new model has been saved!\n')
# Out:
# Epoch 1/200
# 30/30 [==============================] - 173s 6s/step - loss: 1.4092 - accuracy: 0.7283
# Epoch 2/200
# 30/30 [==============================] - 176s 6s/step - loss: 0.8306 - accuracy: 0.7749
# Epoch 3/200
# 30/30 [==============================] - 180s 6s/step - loss: 0.5980 - accuracy: 0.8125
# Epoch 4/200
# 30/30 [==============================] - 176s 6s/step - loss: 0.4777 - accuracy: 0.8299
# Epoch 5/200
# 30/30 [==============================] - 174s 6s/step - loss: 0.4104 - accuracy: 0.8533
# Epoch 6/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.4008 - accuracy: 0.8622
# Epoch 7/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.3399 - accuracy: 0.8758
# Epoch 8/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.2887 - accuracy: 0.8929
# Epoch 9/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.2798 - accuracy: 0.8976
# Epoch 10/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.2571 - accuracy: 0.9053
# Epoch 11/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.2359 - accuracy: 0.9170
# Epoch 12/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.2133 - accuracy: 0.9216
# Epoch 13/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.2033 - accuracy: 0.9263
# Epoch 14/200
# 30/30 [==============================] - 174s 6s/step - loss: 0.1802 - accuracy: 0.9367
# Epoch 15/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1837 - accuracy: 0.9354
# Epoch 16/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.1773 - accuracy: 0.9372
# Epoch 17/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1595 - accuracy: 0.9475
# Epoch 18/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.1564 - accuracy: 0.9474
# Epoch 19/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1539 - accuracy: 0.9478
# Epoch 20/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.1366 - accuracy: 0.9488
# Epoch 21/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1344 - accuracy: 0.9543
# Epoch 22/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1356 - accuracy: 0.9558
# Epoch 23/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1251 - accuracy: 0.9604
# Epoch 24/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1163 - accuracy: 0.9609
# Epoch 25/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1077 - accuracy: 0.9629
# Epoch 26/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0971 - accuracy: 0.9675
# Epoch 27/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.1005 - accuracy: 0.9659
# Epoch 28/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0935 - accuracy: 0.9697
# Epoch 29/200
# 30/30 [==============================] - 174s 6s/step - loss: 0.0966 - accuracy: 0.9679
# Epoch 30/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0973 - accuracy: 0.9708
# Epoch 31/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0981 - accuracy: 0.9661
# Epoch 32/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0976 - accuracy: 0.9700
# Epoch 33/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0954 - accuracy: 0.9700
# Epoch 34/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0894 - accuracy: 0.9704
# Epoch 35/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0824 - accuracy: 0.9721
# Epoch 36/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0851 - accuracy: 0.9737
# Epoch 37/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0813 - accuracy: 0.9742
# Epoch 38/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0769 - accuracy: 0.9739
# Epoch 39/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0669 - accuracy: 0.9801
# Epoch 40/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0773 - accuracy: 0.9732
# Epoch 41/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0822 - accuracy: 0.9758
# Epoch 42/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0706 - accuracy: 0.9771
# Epoch 43/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0635 - accuracy: 0.9787
# Epoch 44/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0647 - accuracy: 0.9804
# Epoch 45/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0628 - accuracy: 0.9775
# Epoch 46/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0646 - accuracy: 0.9808
# Epoch 47/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0672 - accuracy: 0.9805
# Epoch 48/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0647 - accuracy: 0.9787
# Epoch 49/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0609 - accuracy: 0.9809
# Epoch 50/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0648 - accuracy: 0.9792
# Epoch 51/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0681 - accuracy: 0.9793
# Epoch 52/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0611 - accuracy: 0.9796
# Epoch 53/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0638 - accuracy: 0.9803
# Epoch 54/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0655 - accuracy: 0.9782
# Epoch 55/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0651 - accuracy: 0.9804
# Epoch 56/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0535 - accuracy: 0.9818
# Epoch 57/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0595 - accuracy: 0.9800
# Epoch 58/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0565 - accuracy: 0.9814
# Epoch 59/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0529 - accuracy: 0.9826
# Epoch 60/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0564 - accuracy: 0.9824
# Epoch 61/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0523 - accuracy: 0.9825
# Epoch 62/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0545 - accuracy: 0.9824
# Epoch 63/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0510 - accuracy: 0.9849
# Epoch 64/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0469 - accuracy: 0.9837
# Epoch 65/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0492 - accuracy: 0.9847
# Epoch 66/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0512 - accuracy: 0.9839
# Epoch 67/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0473 - accuracy: 0.9846
# Epoch 68/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0486 - accuracy: 0.9826
# Epoch 69/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0471 - accuracy: 0.9853
# Epoch 70/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0414 - accuracy: 0.9864
# Epoch 71/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0529 - accuracy: 0.9833
# Epoch 72/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0567 - accuracy: 0.9814
# Epoch 73/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0436 - accuracy: 0.9859
# Epoch 74/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0517 - accuracy: 0.9834
# Epoch 75/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0484 - accuracy: 0.9842
# Epoch 76/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0470 - accuracy: 0.9846
# Epoch 77/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0420 - accuracy: 0.9855
# Epoch 78/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0471 - accuracy: 0.9851
# Epoch 79/200
# 30/30 [==============================] - 175s 6s/step - loss: 0.0411 - accuracy: 0.9883
# Epoch 80/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0442 - accuracy: 0.9868
# Epoch 81/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0459 - accuracy: 0.9855
# Epoch 82/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0414 - accuracy: 0.9847
# Epoch 83/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0429 - accuracy: 0.9867
# Epoch 84/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0467 - accuracy: 0.9861
# Epoch 85/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0498 - accuracy: 0.9845
# Epoch 86/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0611 - accuracy: 0.9845
# Epoch 87/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0414 - accuracy: 0.9861
# Epoch 88/200
# 30/30 [==============================] - 174s 6s/step - loss: 0.0476 - accuracy: 0.9845
# Epoch 89/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0462 - accuracy: 0.9851
# Epoch 90/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0437 - accuracy: 0.9859
# Epoch 91/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0481 - accuracy: 0.9861
# Epoch 92/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0440 - accuracy: 0.9846
# Epoch 93/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0508 - accuracy: 0.9857
# Epoch 94/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0371 - accuracy: 0.9893
# Epoch 95/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0404 - accuracy: 0.9867
# Epoch 96/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0368 - accuracy: 0.9883
# Epoch 97/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0327 - accuracy: 0.9888
# Epoch 98/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0459 - accuracy: 0.9872
# Epoch 99/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0442 - accuracy: 0.9878
# Epoch 100/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0350 - accuracy: 0.9880
# Epoch 101/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0331 - accuracy: 0.9888
# Epoch 102/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0408 - accuracy: 0.9859
# Epoch 103/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0397 - accuracy: 0.9870
# Epoch 104/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0351 - accuracy: 0.9886
# Epoch 105/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0373 - accuracy: 0.9878
# Epoch 106/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0319 - accuracy: 0.9895
# Epoch 107/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0363 - accuracy: 0.9886
# Epoch 108/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0307 - accuracy: 0.9905
# Epoch 109/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0450 - accuracy: 0.9879
# Epoch 110/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0266 - accuracy: 0.9920
# Epoch 111/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0283 - accuracy: 0.9913
# Epoch 112/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0313 - accuracy: 0.9896
# Epoch 113/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0377 - accuracy: 0.9887
# Epoch 114/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0317 - accuracy: 0.9887
# Epoch 115/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0372 - accuracy: 0.9900
# Epoch 116/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0349 - accuracy: 0.9884
# Epoch 117/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0303 - accuracy: 0.9905
# Epoch 118/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0329 - accuracy: 0.9893
# Epoch 119/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0309 - accuracy: 0.9896
# Epoch 120/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0345 - accuracy: 0.9888
# Epoch 121/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0366 - accuracy: 0.9897
# Epoch 122/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0296 - accuracy: 0.9911
# Epoch 123/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0273 - accuracy: 0.9916
# Epoch 124/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0334 - accuracy: 0.9888
# Epoch 125/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0384 - accuracy: 0.9884
# Epoch 126/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0391 - accuracy: 0.9875
# Epoch 127/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0266 - accuracy: 0.9917
# Epoch 128/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0357 - accuracy: 0.9891
# Epoch 129/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0333 - accuracy: 0.9904
# Epoch 130/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0340 - accuracy: 0.9878
# Epoch 131/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0293 - accuracy: 0.9907
# Epoch 132/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0304 - accuracy: 0.9897
# Epoch 133/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0248 - accuracy: 0.9911
# Epoch 134/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0333 - accuracy: 0.9892
# Epoch 135/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0330 - accuracy: 0.9875
# Epoch 136/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0329 - accuracy: 0.9893
# Epoch 137/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0331 - accuracy: 0.9895
# Epoch 138/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0400 - accuracy: 0.9887
# Epoch 139/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0350 - accuracy: 0.9886
# Epoch 140/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0320 - accuracy: 0.9896
# Epoch 141/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0346 - accuracy: 0.9899
# Epoch 142/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0282 - accuracy: 0.9903
# Epoch 143/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0291 - accuracy: 0.9908
# Epoch 144/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0376 - accuracy: 0.9884
# Epoch 145/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0352 - accuracy: 0.9892
# Epoch 146/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0345 - accuracy: 0.9891
# Epoch 147/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0263 - accuracy: 0.9909
# Epoch 148/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0323 - accuracy: 0.9899
# Epoch 149/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0283 - accuracy: 0.9914
# Epoch 150/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0311 - accuracy: 0.9899
# Epoch 151/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0252 - accuracy: 0.9916
# Epoch 152/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0262 - accuracy: 0.9918
# Epoch 153/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0285 - accuracy: 0.9891
# Epoch 154/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0264 - accuracy: 0.9912
# Epoch 155/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0322 - accuracy: 0.9912
# Epoch 156/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0204 - accuracy: 0.9942
# Epoch 157/200
# 30/30 [==============================] - 176s 6s/step - loss: 0.0308 - accuracy: 0.9891
# Epoch 158/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0268 - accuracy: 0.9921
# Epoch 159/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0260 - accuracy: 0.9920
# Epoch 160/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0239 - accuracy: 0.9918
# Epoch 161/200
# 30/30 [==============================] - 173s 6s/step - loss: 0.0295 - accuracy: 0.9913
# Epoch 162/200
# 30/30 [==============================] - 181s 6s/step - loss: 0.0286 - accuracy: 0.9907
# Epoch 163/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0257 - accuracy: 0.9914
# Epoch 164/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0268 - accuracy: 0.9924
# Epoch 165/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0327 - accuracy: 0.9899
# Epoch 166/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0334 - accuracy: 0.9913
# Epoch 167/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0247 - accuracy: 0.9911
# Epoch 168/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0260 - accuracy: 0.9920
# Epoch 169/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0279 - accuracy: 0.9909
# Epoch 170/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0267 - accuracy: 0.9918
# Epoch 171/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0297 - accuracy: 0.9916
# Epoch 172/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0290 - accuracy: 0.9912
# Epoch 173/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0266 - accuracy: 0.9911
# Epoch 174/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0271 - accuracy: 0.9907
# Epoch 175/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0320 - accuracy: 0.9904
# Epoch 176/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0315 - accuracy: 0.9912
# Epoch 177/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0308 - accuracy: 0.9905
# Epoch 178/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0320 - accuracy: 0.9893
# Epoch 179/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0318 - accuracy: 0.9897
# Epoch 180/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0292 - accuracy: 0.9916
# Epoch 181/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0248 - accuracy: 0.9920
# Epoch 182/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0275 - accuracy: 0.9926
# Epoch 183/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0229 - accuracy: 0.9934
# Epoch 184/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0303 - accuracy: 0.9901
# Epoch 185/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0273 - accuracy: 0.9916
# Epoch 186/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0227 - accuracy: 0.9939
# Epoch 187/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0237 - accuracy: 0.9918
# Epoch 188/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0322 - accuracy: 0.9896
# Epoch 189/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0256 - accuracy: 0.9934
# Epoch 190/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0213 - accuracy: 0.9932
# Epoch 191/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0253 - accuracy: 0.9933
# Epoch 192/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0293 - accuracy: 0.9909
# Epoch 193/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0234 - accuracy: 0.9926
# Epoch 194/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0199 - accuracy: 0.9928
# Epoch 195/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0222 - accuracy: 0.9926
# Epoch 196/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0244 - accuracy: 0.9930
# Epoch 197/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0213 - accuracy: 0.9945
# Epoch 198/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0284 - accuracy: 0.9922
# Epoch 199/200
# 30/30 [==============================] - 172s 6s/step - loss: 0.0329 - accuracy: 0.9907
# Epoch 200/200
# 30/30 [==============================] - 171s 6s/step - loss: 0.0335 - accuracy: 0.9899
# A new model has been saved!

# %% [markdown]
# ## Validation data generation

# %%
data = {}

# 2.  GENERATE VALIDATION DATA
xvalidation = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_VALIDATION, LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS))
yvalidation = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_VALIDATION, NB_CLASSES + 1))

c = 0

# for each frequency
for i_freq in range(len(HEART_RATES)):

    for i_videos in range(NB_VIDEOS_BY_CLASS_VALIDATION):

        t2 = t + (np.random.randint(low=0, high=33) * SAMPLING)   # phase. 33 corresponds to a full phase shift for HR=55 bpm
        signal = a0 + a1 * np.cos(t2 * w * HEART_RATES[i_freq] / 60) + b1 * np.sin(t2 * w * HEART_RATES[i_freq] / 60) + a2 * np.cos(2 * t2 * w * HEART_RATES[i_freq] / 60) + b2 * np.sin(2 * t2 * w * HEART_RATES[i_freq] / 60)
        signal = signal - np.min(signal)
        signal = signal / np.max(signal)

        r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
        trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

        signal = np.expand_dims(signal + trend, 1)
        signal = signal - np.min(signal)

        img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT))
        img = np.transpose(img, axes=(0,2,1))

        img = img / (IMAGE_HEIGHT * IMAGE_WIDTH)
        
        amplitude = np.random.uniform(low=1.5, high=4)
        noise_energy = amplitude * 0.25 * np.random.uniform(low=1, high=10) / 100

        for j in range(0, LENGTH_VIDEO):
            temp = 255 * ((amplitude * img[:,:,j]) + np.random.normal(size=(IMAGE_HEIGHT, IMAGE_WIDTH), loc=0.5, scale=0.25) * noise_energy)
            temp[temp < 0] = 0 
            xvalidation[c,j,:,:,0] = temp.astype('uint8') / 255.0

        xvalidation[c] = xvalidation[c] - np.mean(xvalidation[c])
        yvalidation[c] = labels_cat[i_freq]

        c = c + 1


# constant image noise (gaussian distribution)
for i_videos in range(NB_VIDEOS_BY_CLASS_VALIDATION):
    r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
    trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

    # add a tendancy on noise
    signal = np.expand_dims(trend, 1)
    img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT)) / (IMAGE_HEIGHT * IMAGE_WIDTH)
    img = np.expand_dims(np.transpose(img, axes=(1,0,2)), 3)

    xvalidation[c] = np.expand_dims(np.random.normal(size=(LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH)) / 50, 3) + img
    xvalidation[c] = xvalidation[c] - np.mean(xvalidation[c])
    yvalidation[c] = labels_cat[NB_CLASSES]
    c = c + 1

print('Validation data generation done')
# Out:
# Validation data generation done

# %% [markdown]
# # Testing phase
#
# ## Start a validation session

# %%
model = model_from_json(open(f'{RESULTS_PATH}/model_conv3D.json').read())
model.load_weights(f'{RESULTS_PATH}/weights_conv3D.h5')
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

if(MIXED_DATA == True):
    data = np.load('./dataSplited.npz')
    xvalidation = np.concatenate((xvalidation, data['c']), axis=0)
    yvalidation =  np.concatenate((yvalidation, data['d']), axis=0)

    indices = np.arange(xvalidation.shape[0])
    np.random.shuffle(indices)
    xvalidation = xvalidation[indices]
    yvalidation = yvalidation[indices]
    
model.evaluate(xvalidation, yvalidation, verbose=1)
# Out:
# 238/238 [==============================] - 59s 246ms/step - loss: 1.2349 - accuracy: 0.7538
# [1.2348835468292236, 0.753815770149231]
