# %% [markdown]
# # Implementation of a new rPPG method
#
# ## Part 1 : Notebook for the training of the 3D-CNN model
#
# This jupyter notebook file is composed of different sections allowing to train a Deep Learning neural network to estimate the heart rate of a patient with a simple video sequence.  With this jupyter notebook file, the results of the model can also be validated.
#
# ![General Schema](./img/general_scheme.JPG)
#
# The objective is to generate a functional model in view of integrating it into the pyVHR Framework. ([Link](https://ieeexplore.ieee.org/document/9272290)) ([GitHub](https://github.com/phuselab/pyVHR))
#
# This file is based on the implementation described in the following article :
# Frédéric Bousefsaf, Alain Pruski, Choubeila Maaoui, 3D convolutional neural networks for remote pulse rate measurement and mapping from facial video, Applied Sciences, vol. 9, n° 20, 4364 (2019). ([Link](https://www.mdpi.com/2076-3417/9/20/4364)) ([GitHub](https://github.com/frederic-bousefsaf/ippg-3dcnn))

# %% [markdown]
# ## Importing libraries
#
# Previously , you have to install theses python librairies :
# * tensorflow
# * matplotlib
# * scipy
# * numpy
# * opencv-python

# %%
import os
#RUN ON CPU 
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

#Tensorflow/KERAS
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import ModelCheckpoint
from tensorflow.python.keras.models import model_from_json
from tensorflow.python.keras.layers import ZeroPadding3D, Dense, Activation,Conv3D,MaxPooling3D,AveragePooling3D,Flatten,Dropout
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.models import model_from_json

# Numpy / Matplotlib / OpenCV / Scipy
import numpy as np
import matplotlib.pyplot as plt
import cv2
import scipy.io

# %% [markdown]
# ## Setting of input data
#
# Input Data = IMAGE_WIDTH * IMAGE_HEIGHT * LENGTH_VIDEOS
#
# Units = (X pixels) * (Y pixels) * (N frames)

# %%
LENGTH_VIDEO = 60 #frames
IMAGE_WIDTH = 25 #pixels
IMAGE_HEIGHT = 25 #pixels
IMAGE_CHANNELS = 1 #1 or 2 or 3

#Time notion
SAMPLING = 1 / 30 #30 Hz
t = np.linspace(0, LENGTH_VIDEO * SAMPLING - SAMPLING, LENGTH_VIDEO)

# %% [markdown]
# ## Setting of output data
#
# A class represents an interval \[X,Y\] BPM frequencies.
#
# For example, Class 1 can set the rating between 55 and 57.5 BPM.

# %%
# Available Outputs
HEART_RATES = np.linspace(55, 240, 75)
NB_CLASSES = len(HEART_RATES)

# prepare labels and label categories
labels = np.zeros(NB_CLASSES + 1)

# %% [markdown]
# ## Setting of training session

# %%
# CONSTANTS
NB_VIDEOS_BY_CLASS_TRAIN = 200
NB_VIDEOS_BY_CLASS_VALIDATION = 200

EPOCHS = 160
CONTINUE_TRAINING = True #load or not a old trained model
MIXED_DATA = True

RESULTS_PATH = "./model"

# %% [markdown]
# ## Binarization of classes
#
# Class 1 : (1, 0, 0, 0, 0, ... , 0)
#
# Class 2 : (0, 1, 0, 0, 0, ... , 0)
#
# ...
#
# Class n : (0, 0, 0, 0, 0, ... , 1)

# %%
for i in range(NB_CLASSES + 1):
    labels[i] = i
labels_cat = np_utils.to_categorical(labels)

# %% [markdown]
# ## Definition of the 3D CNN model
#
# ![Model](./img/model_structure.jpg)

# %%
# DEFINE MODEL
model = Sequential()

#feature extraction
model.add(Conv3D(filters=32, kernel_size=(LENGTH_VIDEO-2,IMAGE_HEIGHT-5,IMAGE_WIDTH-5), input_shape=(LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS)))
model.add(MaxPooling3D(pool_size=(2,2,2)))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Flatten())

#Classification
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(NB_CLASSES + 1, activation='softmax'))

model.summary()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 3, 6, 6, 32)       742432
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 1, 3, 3, 32)       0
# _________________________________________________________________
# activation (Activation)      (None, 1, 3, 3, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 3, 3, 32)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 288)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               147968
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 76)                38988
# =================================================================
# Total params: 929,388
# Trainable params: 929,388
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Process for artificial data creation
#
# For more information, the process is described with more detail in the article cited in the introduction. However, here is a summary diagram:
#
# ![Data Generation](./img/data_generation.jpg)
#
#
# Original version of the implementation of this process : [GitHub](https://github.com/frederic-bousefsaf/ippg-3dcnn/tree/master/train)

# %% [markdown]
# ## Trend generation function for artificial data creation

# %%
def generate_trend(length, order, min, max, offset):

    if (order==1):   # linear
        tend = np.linspace(min, max, length)

    elif (order==2): # quadratic
        if (offset==0):
            tend = np.linspace(0, 1, length)
            tend = tend*tend
            tend = tend-min
            tend = max*tend/np.max(tend)

        else:
            tend = tend = np.linspace(-0.5, 0.5, length)
            tend = tend*tend
            tend = tend-min
            tend = 0.5*max*tend/np.max(tend)

    elif (order==3): # cubic
        if (offset==0):
            tend = np.linspace(0, 1, length)
            tend = tend*tend*tend
            tend = tend-min
            tend = max*tend/np.max(tend)

        else:
            tend = tend = np.linspace(-0.5, 0.5, length)
            tend = tend*tend*tend
            tend = tend-min
            tend = 0.5*max*tend/np.max(tend)
    return tend

# %% [markdown]
# ## Trend generation parameters for artificial data creation

# %%
# Tendencies (linear, 2nd order, 3rd order)
TENDANCIES_MIN = (-3,-1,-1)
TENDANCIES_MAX = (3,1,1)
TENDANCIES_ORDER = (1,2,3)

# coefficients for the fitted-ppg method
a0 = 0.440240602542388
a1 = -0.334501803331783
b1 = -0.198990393984879
a2 = -0.050159136439220
b2 = 0.099347477830878
w = 2 * np.pi

# %% [markdown]
# ## Train Data generation

# %%
xtrain = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_TRAIN, LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS))
ytrain = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_TRAIN, NB_CLASSES + 1))

c = 0

for i_freq in range(len(HEART_RATES)):

    for i_videos in range(NB_VIDEOS_BY_CLASS_TRAIN):

        t2 = t + (np.random.randint(low=0, high=33) * SAMPLING)   # phase
        signal = a0 + a1 * np.cos(t2 * w * HEART_RATES[i_freq] / 60) + b1 * np.sin(t2 * w * HEART_RATES[i_freq] / 60) + a2 * np.cos(2 * t2 * w * HEART_RATES[i_freq] / 60) + b2 * np.sin(2 * t2 * w * HEART_RATES[i_freq] / 60)
        signal = signal - np.min(signal)
        signal = signal / np.max(signal)

        r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
        trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

        signal = np.expand_dims(signal + trend, 1)
        signal = signal - np.min(signal)

        img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT))
        img = np.transpose(img, axes=(0,2,1))

        img = img / (IMAGE_HEIGHT * IMAGE_WIDTH)
        
        amplitude = np.random.uniform(low=1.5, high=4)
        noise_energy = amplitude * 0.25 * np.random.uniform(low=1, high=10) / 100

        for j in range(0, LENGTH_VIDEO):
            temp = 255 * ((amplitude * img[:,:,j]) + np.random.normal(size=(IMAGE_HEIGHT, IMAGE_WIDTH), loc=0.5, scale=0.25) * noise_energy)
            temp[temp < 0] = 0 
            xtrain[c,j,:,:,0] = temp.astype('uint8') / 255.0

        xtrain[c] = xtrain[c] - np.mean(xtrain[c])
        ytrain[c] = labels_cat[i_freq]

        c = c + 1


# constant image noise (gaussian distribution)
for i_videos in range(NB_VIDEOS_BY_CLASS_TRAIN):
    r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
    trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

    # add a tendancy on noise
    signal = np.expand_dims(trend, 1)
    img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT)) / (IMAGE_HEIGHT * IMAGE_WIDTH)
    img = np.expand_dims(np.transpose(img, axes=(1,0,2)), 3)

    xtrain[c] = np.expand_dims(np.random.normal(size=(LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH)) / 50, 3) + img
    xtrain[c] = xtrain[c] - np.mean(xtrain[c])
    ytrain[c] = labels_cat[NB_CLASSES]
    c = c + 1

print('Train data generation done.')
# Out:
# Train data generation done.

# %% [markdown]
# # Training phase
#
# ## Start a training session + save

# %%
# load model
if (CONTINUE_TRAINING == True):
    model = model_from_json(open(f'{RESULTS_PATH}/model_conv3D.json').read())
    model.load_weights(f'{RESULTS_PATH}/weights_conv3D.h5')
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
if(MIXED_DATA == True):
    data = np.load('./dataSplited.npz')
    xtrain = np.concatenate((xtrain, data['a']), axis=0)
    ytrain =  np.concatenate((ytrain, data['b']), axis=0)

    indices = np.arange(xtrain.shape[0])
    np.random.shuffle(indices)
    xtrain = xtrain[indices]
    ytrain = ytrain[indices]
    
#start training
model.fit(xtrain, ytrain, epochs = EPOCHS, batch_size=256, verbose=1)

#save data
model_json = model.to_json()
open(f'{RESULTS_PATH}/model_conv3D.json', 'w').write(model_json)
model.save_weights(f'{RESULTS_PATH}/weights_conv3D.h5', overwrite=True)
print('A new model has been saved!\n')
# Out:
# Epoch 1/160
# 66/66 [==============================] - 320s 5s/step - loss: 1.0012 - accuracy: 0.6844
# Epoch 2/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.8560 - accuracy: 0.7203
# Epoch 3/160
# 66/66 [==============================] - 317s 5s/step - loss: 0.8004 - accuracy: 0.7360
# Epoch 4/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.7489 - accuracy: 0.7568
# Epoch 5/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.7233 - accuracy: 0.7803
# Epoch 6/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.6604 - accuracy: 0.7917
# Epoch 7/160
# 66/66 [==============================] - 322s 5s/step - loss: 0.6270 - accuracy: 0.8009
# Epoch 8/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.5971 - accuracy: 0.8154
# Epoch 9/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.5801 - accuracy: 0.8233
# Epoch 10/160
# 66/66 [==============================] - 322s 5s/step - loss: 0.5313 - accuracy: 0.8383
# Epoch 11/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.5403 - accuracy: 0.8403
# Epoch 12/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.4936 - accuracy: 0.8489
# Epoch 13/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.4837 - accuracy: 0.8558
# Epoch 14/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.4817 - accuracy: 0.8570
# Epoch 15/160
# 66/66 [==============================] - 330s 5s/step - loss: 0.4692 - accuracy: 0.8610
# Epoch 16/160
# 66/66 [==============================] - 327s 5s/step - loss: 0.4608 - accuracy: 0.8646
# Epoch 17/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.4414 - accuracy: 0.8700
# Epoch 18/160
# 66/66 [==============================] - 336s 5s/step - loss: 0.4222 - accuracy: 0.8694
# Epoch 19/160
# 66/66 [==============================] - 333s 5s/step - loss: 0.4250 - accuracy: 0.8755
# Epoch 20/160
# 66/66 [==============================] - 325s 5s/step - loss: 0.4096 - accuracy: 0.8792
# Epoch 21/160
# 66/66 [==============================] - 327s 5s/step - loss: 0.4328 - accuracy: 0.8763
# Epoch 22/160
# 66/66 [==============================] - 329s 5s/step - loss: 0.4162 - accuracy: 0.8816
# Epoch 23/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.4003 - accuracy: 0.8829
# Epoch 24/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.3899 - accuracy: 0.8879
# Epoch 25/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.3935 - accuracy: 0.8866
# Epoch 26/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3983 - accuracy: 0.8875
# Epoch 27/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3856 - accuracy: 0.8858
# Epoch 28/160
# 66/66 [==============================] - 326s 5s/step - loss: 0.3880 - accuracy: 0.8853
# Epoch 29/160
# 66/66 [==============================] - 325s 5s/step - loss: 0.3820 - accuracy: 0.8888
# Epoch 30/160
# 66/66 [==============================] - 326s 5s/step - loss: 0.3838 - accuracy: 0.8907
# Epoch 31/160
# 66/66 [==============================] - 324s 5s/step - loss: 0.3569 - accuracy: 0.8919
# Epoch 32/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3562 - accuracy: 0.8920
# Epoch 33/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3648 - accuracy: 0.8929
# Epoch 34/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3706 - accuracy: 0.8944
# Epoch 35/160
# 66/66 [==============================] - 324s 5s/step - loss: 0.3685 - accuracy: 0.8905
# Epoch 36/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3694 - accuracy: 0.8951
# Epoch 37/160
# 66/66 [==============================] - 326s 5s/step - loss: 0.3712 - accuracy: 0.8927
# Epoch 38/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.3632 - accuracy: 0.8954
# Epoch 39/160
# 66/66 [==============================] - 325s 5s/step - loss: 0.3477 - accuracy: 0.8983
# Epoch 40/160
# 66/66 [==============================] - 326s 5s/step - loss: 0.3533 - accuracy: 0.8978
# Epoch 41/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3488 - accuracy: 0.8970
# Epoch 42/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3360 - accuracy: 0.8988
# Epoch 43/160
# 66/66 [==============================] - 322s 5s/step - loss: 0.3348 - accuracy: 0.8979
# Epoch 44/160
# 66/66 [==============================] - 324s 5s/step - loss: 0.3390 - accuracy: 0.8985
# Epoch 45/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3363 - accuracy: 0.8985
# Epoch 46/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3453 - accuracy: 0.8988
# Epoch 47/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3401 - accuracy: 0.8995
# Epoch 48/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3435 - accuracy: 0.8976
# Epoch 49/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3410 - accuracy: 0.9022
# Epoch 50/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3347 - accuracy: 0.9014
# Epoch 51/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3373 - accuracy: 0.8994
# Epoch 52/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3306 - accuracy: 0.9014
# Epoch 53/160
# 66/66 [==============================] - 322s 5s/step - loss: 0.3283 - accuracy: 0.9014
# Epoch 54/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3267 - accuracy: 0.9007
# Epoch 55/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3195 - accuracy: 0.9044
# Epoch 56/160
# 66/66 [==============================] - 322s 5s/step - loss: 0.3285 - accuracy: 0.9027
# Epoch 57/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3245 - accuracy: 0.9012
# Epoch 58/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3302 - accuracy: 0.9017
# Epoch 59/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3278 - accuracy: 0.9039
# Epoch 60/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3208 - accuracy: 0.9005
# Epoch 61/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3127 - accuracy: 0.9062
# Epoch 62/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3076 - accuracy: 0.9072
# Epoch 63/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3187 - accuracy: 0.9029
# Epoch 64/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3185 - accuracy: 0.9026
# Epoch 65/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.3087 - accuracy: 0.9040
# Epoch 66/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.3184 - accuracy: 0.8994
# Epoch 67/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3306 - accuracy: 0.9056
# Epoch 68/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3131 - accuracy: 0.9074
# Epoch 69/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3210 - accuracy: 0.9038
# Epoch 70/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3168 - accuracy: 0.9032
# Epoch 71/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3113 - accuracy: 0.9053
# Epoch 72/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.3185 - accuracy: 0.9040
# Epoch 73/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3306 - accuracy: 0.9057
# Epoch 74/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3356 - accuracy: 0.9017
# Epoch 75/160
# 66/66 [==============================] - 317s 5s/step - loss: 0.3151 - accuracy: 0.9045
# Epoch 76/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.3266 - accuracy: 0.9007
# Epoch 77/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3214 - accuracy: 0.9047
# Epoch 78/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3108 - accuracy: 0.9065
# Epoch 79/160
# 66/66 [==============================] - 316s 5s/step - loss: 0.3169 - accuracy: 0.9048
# Epoch 80/160
# 66/66 [==============================] - 316s 5s/step - loss: 0.3124 - accuracy: 0.9048
# Epoch 81/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3143 - accuracy: 0.9053
# Epoch 82/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3066 - accuracy: 0.9068
# Epoch 83/160
# 66/66 [==============================] - 316s 5s/step - loss: 0.3051 - accuracy: 0.9060
# Epoch 84/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.3104 - accuracy: 0.9078
# Epoch 85/160
# 66/66 [==============================] - 314s 5s/step - loss: 0.3139 - accuracy: 0.9070
# Epoch 86/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.3138 - accuracy: 0.9098
# Epoch 87/160
# 66/66 [==============================] - 314s 5s/step - loss: 0.3118 - accuracy: 0.9065
# Epoch 88/160
# 66/66 [==============================] - 312s 5s/step - loss: 0.3039 - accuracy: 0.9081
# Epoch 89/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3031 - accuracy: 0.9106
# Epoch 90/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.2994 - accuracy: 0.9077
# Epoch 91/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.3038 - accuracy: 0.9089
# Epoch 92/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.3050 - accuracy: 0.9092
# Epoch 93/160
# 66/66 [==============================] - 317s 5s/step - loss: 0.3122 - accuracy: 0.9083
# Epoch 94/160
# 66/66 [==============================] - 316s 5s/step - loss: 0.3062 - accuracy: 0.9080
# Epoch 95/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.3012 - accuracy: 0.9092
# Epoch 96/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.2970 - accuracy: 0.9068
# Epoch 97/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3066 - accuracy: 0.9084
# Epoch 98/160
# 66/66 [==============================] - 322s 5s/step - loss: 0.3023 - accuracy: 0.9079
# Epoch 99/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3081 - accuracy: 0.9066
# Epoch 100/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3081 - accuracy: 0.9077
# Epoch 101/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3037 - accuracy: 0.9081
# Epoch 102/160
# 66/66 [==============================] - 316s 5s/step - loss: 0.3014 - accuracy: 0.9096
# Epoch 103/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.3003 - accuracy: 0.9081
# Epoch 104/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.2985 - accuracy: 0.9110
# Epoch 105/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.2916 - accuracy: 0.9120
# Epoch 106/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3023 - accuracy: 0.9074
# Epoch 107/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3303 - accuracy: 0.9047
# Epoch 108/160
# 66/66 [==============================] - 314s 5s/step - loss: 0.2998 - accuracy: 0.9095
# Epoch 109/160
# 66/66 [==============================] - 310s 5s/step - loss: 0.3122 - accuracy: 0.9065
# Epoch 110/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.2949 - accuracy: 0.9096
# Epoch 111/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.2895 - accuracy: 0.9102
# Epoch 112/160
# 66/66 [==============================] - 317s 5s/step - loss: 0.3313 - accuracy: 0.9042
# Epoch 113/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3063 - accuracy: 0.9073
# Epoch 114/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.2980 - accuracy: 0.9096
# Epoch 115/160
# 66/66 [==============================] - 316s 5s/step - loss: 0.2951 - accuracy: 0.9102
# Epoch 116/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.2925 - accuracy: 0.9096
# Epoch 117/160
# 66/66 [==============================] - 314s 5s/step - loss: 0.3067 - accuracy: 0.9087
# Epoch 118/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.2827 - accuracy: 0.9124
# Epoch 119/160
# 66/66 [==============================] - 312s 5s/step - loss: 0.2880 - accuracy: 0.9131
# Epoch 120/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.2894 - accuracy: 0.9134
# Epoch 121/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.2920 - accuracy: 0.9123
# Epoch 122/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.2957 - accuracy: 0.9093
# Epoch 123/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.2989 - accuracy: 0.9110
# Epoch 124/160
# 66/66 [==============================] - 314s 5s/step - loss: 0.2983 - accuracy: 0.9116
# Epoch 125/160
# 66/66 [==============================] - 314s 5s/step - loss: 0.3000 - accuracy: 0.9111
# Epoch 126/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.2963 - accuracy: 0.9115
# Epoch 127/160
# 66/66 [==============================] - 315s 5s/step - loss: 0.2986 - accuracy: 0.9098
# Epoch 128/160
# 66/66 [==============================] - 316s 5s/step - loss: 0.2955 - accuracy: 0.9106
# Epoch 129/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.3228 - accuracy: 0.9094
# Epoch 130/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3123 - accuracy: 0.9104
# Epoch 131/160
# 66/66 [==============================] - 311s 5s/step - loss: 0.3008 - accuracy: 0.9114
# Epoch 132/160
# 66/66 [==============================] - 312s 5s/step - loss: 0.2893 - accuracy: 0.9128
# Epoch 133/160
# 66/66 [==============================] - 312s 5s/step - loss: 0.2910 - accuracy: 0.9111
# Epoch 134/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.2944 - accuracy: 0.9137
# Epoch 135/160
# 66/66 [==============================] - 318s 5s/step - loss: 0.2894 - accuracy: 0.9113
# Epoch 136/160
# 66/66 [==============================] - 317s 5s/step - loss: 0.2958 - accuracy: 0.9105
# Epoch 137/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.2922 - accuracy: 0.9116
# Epoch 138/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.3058 - accuracy: 0.9083
# Epoch 139/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.2973 - accuracy: 0.9120
# Epoch 140/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3045 - accuracy: 0.9112
# Epoch 141/160
# 66/66 [==============================] - 325s 5s/step - loss: 0.3067 - accuracy: 0.9113
# Epoch 142/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3008 - accuracy: 0.9104
# Epoch 143/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3053 - accuracy: 0.9124
# Epoch 144/160
# 66/66 [==============================] - 329s 5s/step - loss: 0.3862 - accuracy: 0.9080
# Epoch 145/160
# 66/66 [==============================] - 323s 5s/step - loss: 0.3181 - accuracy: 0.9077
# Epoch 146/160
# 66/66 [==============================] - 324s 5s/step - loss: 0.3234 - accuracy: 0.9102
# Epoch 147/160
# 66/66 [==============================] - 330s 5s/step - loss: 0.3099 - accuracy: 0.9115
# Epoch 148/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3133 - accuracy: 0.9095
# Epoch 149/160
# 66/66 [==============================] - 332s 5s/step - loss: 0.2945 - accuracy: 0.9134
# Epoch 150/160
# 66/66 [==============================] - 334s 5s/step - loss: 0.3162 - accuracy: 0.9093
# Epoch 151/160
# 66/66 [==============================] - 329s 5s/step - loss: 0.3054 - accuracy: 0.9122
# Epoch 152/160
# 66/66 [==============================] - 332s 5s/step - loss: 0.3066 - accuracy: 0.9124
# Epoch 153/160
# 66/66 [==============================] - 329s 5s/step - loss: 0.3091 - accuracy: 0.9113
# Epoch 154/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.2951 - accuracy: 0.9129
# Epoch 155/160
# 66/66 [==============================] - 325s 5s/step - loss: 0.3024 - accuracy: 0.9144
# Epoch 156/160
# 66/66 [==============================] - 331s 5s/step - loss: 0.3119 - accuracy: 0.9132
# Epoch 157/160
# 66/66 [==============================] - 320s 5s/step - loss: 0.3108 - accuracy: 0.9105
# Epoch 158/160
# 66/66 [==============================] - 324s 5s/step - loss: 0.3102 - accuracy: 0.9098
# Epoch 159/160
# 66/66 [==============================] - 321s 5s/step - loss: 0.3000 - accuracy: 0.9121
# Epoch 160/160
# 66/66 [==============================] - 319s 5s/step - loss: 0.3050 - accuracy: 0.9129
# A new model has been saved!

# %% [markdown]
# ## Validation data generation

# %%
data = {}

# 2.  GENERATE VALIDATION DATA
xvalidation = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_VALIDATION, LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS))
yvalidation = np.zeros(shape=((NB_CLASSES + 1) * NB_VIDEOS_BY_CLASS_VALIDATION, NB_CLASSES + 1))

c = 0

# for each frequency
for i_freq in range(len(HEART_RATES)):

    for i_videos in range(NB_VIDEOS_BY_CLASS_VALIDATION):

        t2 = t + (np.random.randint(low=0, high=33) * SAMPLING)   # phase. 33 corresponds to a full phase shift for HR=55 bpm
        signal = a0 + a1 * np.cos(t2 * w * HEART_RATES[i_freq] / 60) + b1 * np.sin(t2 * w * HEART_RATES[i_freq] / 60) + a2 * np.cos(2 * t2 * w * HEART_RATES[i_freq] / 60) + b2 * np.sin(2 * t2 * w * HEART_RATES[i_freq] / 60)
        signal = signal - np.min(signal)
        signal = signal / np.max(signal)

        r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
        trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

        signal = np.expand_dims(signal + trend, 1)
        signal = signal - np.min(signal)

        img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT))
        img = np.transpose(img, axes=(0,2,1))

        img = img / (IMAGE_HEIGHT * IMAGE_WIDTH)
        
        amplitude = np.random.uniform(low=1.5, high=4)
        noise_energy = amplitude * 0.25 * np.random.uniform(low=1, high=10) / 100

        for j in range(0, LENGTH_VIDEO):
            temp = 255 * ((amplitude * img[:,:,j]) + np.random.normal(size=(IMAGE_HEIGHT, IMAGE_WIDTH), loc=0.5, scale=0.25) * noise_energy)
            temp[temp < 0] = 0 
            xvalidation[c,j,:,:,0] = temp.astype('uint8') / 255.0

        xvalidation[c] = xvalidation[c] - np.mean(xvalidation[c])
        yvalidation[c] = labels_cat[i_freq]

        c = c + 1


# constant image noise (gaussian distribution)
for i_videos in range(NB_VIDEOS_BY_CLASS_VALIDATION):
    r = np.random.randint(low=0, high=len(TENDANCIES_MAX))
    trend = generate_trend(len(t), TENDANCIES_ORDER[r], 0, np.random.uniform(low=TENDANCIES_MIN[r], high=TENDANCIES_MAX[r]), np.random.randint(low=0, high=2))

    # add a tendancy on noise
    signal = np.expand_dims(trend, 1)
    img = np.tile(signal, (IMAGE_WIDTH, 1, IMAGE_HEIGHT)) / (IMAGE_HEIGHT * IMAGE_WIDTH)
    img = np.expand_dims(np.transpose(img, axes=(1,0,2)), 3)

    xvalidation[c] = np.expand_dims(np.random.normal(size=(LENGTH_VIDEO, IMAGE_HEIGHT, IMAGE_WIDTH)) / 50, 3) + img
    xvalidation[c] = xvalidation[c] - np.mean(xvalidation[c])
    yvalidation[c] = labels_cat[NB_CLASSES]
    c = c + 1

print('Validation data generation done')
# Out:
# Validation data generation done

# %% [markdown]
# # Testing phase
#
# ## Start a validation session

# %%
model = model_from_json(open(f'{RESULTS_PATH}/model_conv3D.json').read())
model.load_weights(f'{RESULTS_PATH}/weights_conv3D.h5')
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

if(MIXED_DATA == True):
    data = np.load('./dataSplited.npz')
    xvalidation = np.concatenate((xvalidation, data['c']), axis=0)
    yvalidation =  np.concatenate((yvalidation, data['d']), axis=0)

    indices = np.arange(xvalidation.shape[0])
    np.random.shuffle(indices)
    xvalidation = xvalidation[indices]
    yvalidation = yvalidation[indices]
    
model.evaluate(xvalidation, yvalidation, verbose=1)
# Out:
# 481/481 [==============================] - 162s 338ms/step - loss: 1.1777 - accuracy: 0.7536
# [1.177677869796753, 0.7535637617111206]
